# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key+"&q="+cities[0]

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the d1ate to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description" : city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | louiseville
# Processing Record 2 of Set 1 | evensk
# Processing Record 3 of Set 1 | klaksvik
# Processing Record 4 of Set 1 | sidi bu zayd
# City not found. Skipping...
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | isangel
# Processing Record 8 of Set 1 | manono
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 1 | asfi
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | hoorn
# Processing Record 19 of Set 1 | bambous virieux
# Processing Record 20 of Set 1 | touros
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | newport
# Processing Record 24 of Set 1 | nizhniy tsasuchey
# Processing Record 25 of Set 1 | shimoda
# Processing Record 26 of Set 1 | berlevag
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | pangai
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | tamandare
# Processing Record 32 of Set 1 | kutahya
# Processing Record 33 of Set 1 | portland
# Processing Record 34 of Set 1 | hasaki
# Processing Record 35 of Set 1 | asahi
# Processing Record 36 of Set 1 | fort nelson
# Processing Record 37 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 1 | ribeira grande
# Processing Record 39 of Set 1 | batemans bay
# Processing Record 40 of Set 1 | pevek
# Processing Record 41 of Set 1 | la palma
# Processing Record 42 of Set 1 | gat
# Processing Record 43 of Set 1 | aksu
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | bubaque
# Processing Record 49 of Set 1 | hofn
# Processing Record 50 of Set 1 | latung
# Processing Record 1 of Set 2 | dingle
# Processing Record 2 of Set 2 | westport
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | arman
# Processing Record 5 of Set 2 | zhangye
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | ler
# Processing Record 8 of Set 2 | saint-pierre
# Processing Record 9 of Set 2 | vardo
# Processing Record 10 of Set 2 | mahebourg
# Processing Record 11 of Set 2 | salisbury
# Processing Record 12 of Set 2 | nicoya
# Processing Record 13 of Set 2 | evans
# Processing Record 14 of Set 2 | tari
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | quatre cocos
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | atambua
# Processing Record 20 of Set 2 | srednekolymsk
# Processing Record 21 of Set 2 | yalutorovsk
# Processing Record 22 of Set 2 | bilibino
# Processing Record 23 of Set 2 | laguna
# Processing Record 24 of Set 2 | kraliky
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | ola
# Processing Record 27 of Set 2 | marawi
# Processing Record 28 of Set 2 | dickinson
# Processing Record 29 of Set 2 | castro
# Processing Record 30 of Set 2 | flinders
# Processing Record 31 of Set 2 | nara
# Processing Record 32 of Set 2 | mataura
# Processing Record 33 of Set 2 | pacific grove
# Processing Record 34 of Set 2 | wuwei
# Processing Record 35 of Set 2 | yumen
# Processing Record 36 of Set 2 | faanui
# Processing Record 37 of Set 2 | parit buntar
# Processing Record 38 of Set 2 | busselton
# Processing Record 39 of Set 2 | pechenga
# Processing Record 40 of Set 2 | watertown
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | mount isa
# Processing Record 43 of Set 2 | lavrentiya
# Processing Record 44 of Set 2 | saskylakh
# Processing Record 45 of Set 2 | port-gentil
# Processing Record 46 of Set 2 | okha
# Processing Record 47 of Set 2 | lagoa
# Processing Record 48 of Set 2 | hermanus
# Processing Record 49 of Set 2 | ushuaia
# Processing Record 50 of Set 2 | hilo
# Processing Record 1 of Set 3 | lasa
# Processing Record 2 of Set 3 | kiunga
# Processing Record 3 of Set 3 | amapa
# Processing Record 4 of Set 3 | zhangjiakou
# Processing Record 5 of Set 3 | iskateley
# Processing Record 6 of Set 3 | acari
# Processing Record 7 of Set 3 | juneau
# Processing Record 8 of Set 3 | san jorge
# Processing Record 9 of Set 3 | tigil
# Processing Record 10 of Set 3 | lumphat
# Processing Record 11 of Set 3 | sibu
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | pudozh
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 3 | tautira
# Processing Record 17 of Set 3 | lebu
# Processing Record 18 of Set 3 | mayo
# Processing Record 19 of Set 3 | paamiut
# Processing Record 20 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 3 | provideniya
# Processing Record 22 of Set 3 | ancud
# Processing Record 23 of Set 3 | kesinga
# Processing Record 24 of Set 3 | hithadhoo
# Processing Record 25 of Set 3 | qasigiannguit
# Processing Record 26 of Set 3 | tabou
# Processing Record 27 of Set 3 | pangnirtung
# Processing Record 28 of Set 3 | ituni
# City not found. Skipping...
# Processing Record 29 of Set 3 | poum
# Processing Record 30 of Set 3 | kaspican
# City not found. Skipping...
# Processing Record 31 of Set 3 | margate
# Processing Record 32 of Set 3 | thompson
# Processing Record 33 of Set 3 | velika plana
# Processing Record 34 of Set 3 | arraial do cabo
# Processing Record 35 of Set 3 | seoul
# Processing Record 36 of Set 3 | tuatapere
# Processing Record 37 of Set 3 | yellowknife
# Processing Record 38 of Set 3 | gushi
# Processing Record 39 of Set 3 | torbay
# Processing Record 40 of Set 3 | ekibastuz
# Processing Record 41 of Set 3 | paka
# Processing Record 42 of Set 3 | hovd
# Processing Record 43 of Set 3 | saldanha
# Processing Record 44 of Set 3 | souillac
# Processing Record 45 of Set 3 | mehamn
# Processing Record 46 of Set 3 | neustadt
# Processing Record 47 of Set 3 | faya
# Processing Record 48 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 49 of Set 3 | bathsheba
# Processing Record 50 of Set 3 | ponta do sol
# Processing Record 1 of Set 4 | barrow
# Processing Record 2 of Set 4 | el balyana
# City not found. Skipping...
# Processing Record 3 of Set 4 | flin flon
# Processing Record 4 of Set 4 | sabang
# Processing Record 5 of Set 4 | coquimbo
# Processing Record 6 of Set 4 | zamora
# Processing Record 7 of Set 4 | chokurdakh
# Processing Record 8 of Set 4 | chyhyryn
# Processing Record 9 of Set 4 | longyearbyen
# Processing Record 10 of Set 4 | bonthe
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | hobyo
# Processing Record 13 of Set 4 | cabo san lucas
# Processing Record 14 of Set 4 | sept-iles
# Processing Record 15 of Set 4 | half moon bay
# Processing Record 16 of Set 4 | marzuq
# Processing Record 17 of Set 4 | buenos aires
# Processing Record 18 of Set 4 | broken hill
# Processing Record 19 of Set 4 | tiksi
# Processing Record 20 of Set 4 | tilichiki
# Processing Record 21 of Set 4 | rundu
# Processing Record 22 of Set 4 | high level
# Processing Record 23 of Set 4 | vreed en hoop
# City not found. Skipping...
# Processing Record 24 of Set 4 | labuan
# Processing Record 25 of Set 4 | mata
# Processing Record 26 of Set 4 | caramay
# Processing Record 27 of Set 4 | ketchikan
# Processing Record 28 of Set 4 | port elizabeth
# Processing Record 29 of Set 4 | nevsehir
# Processing Record 30 of Set 4 | segezha
# Processing Record 31 of Set 4 | sitka
# Processing Record 32 of Set 4 | bengkulu
# Processing Record 33 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 4 | kavieng
# Processing Record 35 of Set 4 | dzhubga
# Processing Record 36 of Set 4 | isoka
# Processing Record 37 of Set 4 | fort abbas
# Processing Record 38 of Set 4 | gunjur
# Processing Record 39 of Set 4 | bethel
# Processing Record 40 of Set 4 | esperance
# Processing Record 41 of Set 4 | kuala terengganu
# Processing Record 42 of Set 4 | zhigansk
# Processing Record 43 of Set 4 | boa vista
# Processing Record 44 of Set 4 | upernavik
# Processing Record 45 of Set 4 | caravelas
# Processing Record 46 of Set 4 | beloha
# Processing Record 47 of Set 4 | kyra
# Processing Record 48 of Set 4 | cockburn town
# Processing Record 49 of Set 4 | ak-dovurak
# Processing Record 50 of Set 4 | leninskoye
# Processing Record 1 of Set 5 | sao filipe
# Processing Record 2 of Set 5 | gornopravdinsk
# Processing Record 3 of Set 5 | port alfred
# Processing Record 4 of Set 5 | komsomolskiy
# Processing Record 5 of Set 5 | sabha
# Processing Record 6 of Set 5 | kehra
# Processing Record 7 of Set 5 | aakirkeby
# City not found. Skipping...
# Processing Record 8 of Set 5 | alugan
# Processing Record 9 of Set 5 | itoman
# Processing Record 10 of Set 5 | ciudad bolivar
# Processing Record 11 of Set 5 | lompoc
# Processing Record 12 of Set 5 | bahia blanca
# Processing Record 13 of Set 5 | darhan
# Processing Record 14 of Set 5 | touho
# Processing Record 15 of Set 5 | hamilton
# Processing Record 16 of Set 5 | vredendal
# Processing Record 17 of Set 5 | sao joao da barra
# Processing Record 18 of Set 5 | nome
# Processing Record 19 of Set 5 | auburn
# Processing Record 20 of Set 5 | iqaluit
# Processing Record 21 of Set 5 | mar del plata
# Processing Record 22 of Set 5 | gorom-gorom
# Processing Record 23 of Set 5 | kibaya
# Processing Record 24 of Set 5 | codrington
# Processing Record 25 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 5 | kholmogory
# Processing Record 27 of Set 5 | airai
# Processing Record 28 of Set 5 | palpa
# Processing Record 29 of Set 5 | victoria
# Processing Record 30 of Set 5 | katherine
# Processing Record 31 of Set 5 | talnakh
# Processing Record 32 of Set 5 | saint-leu
# Processing Record 33 of Set 5 | bondo
# Processing Record 34 of Set 5 | kudahuvadhoo
# Processing Record 35 of Set 5 | veraval
# Processing Record 36 of Set 5 | vila velha
# Processing Record 37 of Set 5 | petrovskoye
# Processing Record 38 of Set 5 | husavik
# Processing Record 39 of Set 5 | benguela
# Processing Record 40 of Set 5 | oregon
# Processing Record 41 of Set 5 | pailon
# Processing Record 42 of Set 5 | coban
# Processing Record 43 of Set 5 | naze
# Processing Record 44 of Set 5 | tam ky
# Processing Record 45 of Set 5 | puerto del rosario
# Processing Record 46 of Set 5 | rawson
# Processing Record 47 of Set 5 | perevoz
# Processing Record 48 of Set 5 | onguday
# Processing Record 49 of Set 5 | bogorodskoye
# Processing Record 50 of Set 5 | port macquarie
# Processing Record 1 of Set 6 | beringovskiy
# Processing Record 2 of Set 6 | neyshabur
# Processing Record 3 of Set 6 | mikhaylovka
# Processing Record 4 of Set 6 | severo-kurilsk
# Processing Record 5 of Set 6 | hashtrud
# Processing Record 6 of Set 6 | constitucion
# Processing Record 7 of Set 6 | aklavik
# Processing Record 8 of Set 6 | tiznit
# Processing Record 9 of Set 6 | dunedin
# Processing Record 10 of Set 6 | kolpashevo
# Processing Record 11 of Set 6 | cidreira
# Processing Record 12 of Set 6 | alta floresta
# Processing Record 13 of Set 6 | hambantota
# Processing Record 14 of Set 6 | georgetown
# Processing Record 15 of Set 6 | lorengau
# Processing Record 16 of Set 6 | alexandria
# Processing Record 17 of Set 6 | kalmunai
# Processing Record 18 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 19 of Set 6 | obo
# Processing Record 20 of Set 6 | nanortalik
# Processing Record 21 of Set 6 | kahului
# Processing Record 22 of Set 6 | sosnovskiy
# City not found. Skipping...
# Processing Record 23 of Set 6 | clyde river
# Processing Record 24 of Set 6 | masuguru
# Processing Record 25 of Set 6 | olinda
# Processing Record 26 of Set 6 | west kilbride
# Processing Record 27 of Set 6 | we
# City not found. Skipping...
# Processing Record 28 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 6 | tachov
# Processing Record 30 of Set 6 | khash
# Processing Record 31 of Set 6 | sisimiut
# Processing Record 32 of Set 6 | acapulco
# Processing Record 33 of Set 6 | drayton valley
# Processing Record 34 of Set 6 | astana
# Processing Record 35 of Set 6 | sisophon
# Processing Record 36 of Set 6 | harper
# Processing Record 37 of Set 6 | gebre guracha
# Processing Record 38 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 6 | mandalgovi
# Processing Record 40 of Set 6 | salalah
# Processing Record 41 of Set 6 | yar-sale
# Processing Record 42 of Set 6 | maldonado
# Processing Record 43 of Set 6 | guerrero negro
# Processing Record 44 of Set 6 | matara
# Processing Record 45 of Set 6 | treinta y tres
# Processing Record 46 of Set 6 | balgazyn
# Processing Record 47 of Set 6 | poronaysk
# Processing Record 48 of Set 6 | mamou
# Processing Record 49 of Set 6 | kavaratti
# Processing Record 50 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 1 of Set 7 | brae
# Processing Record 2 of Set 7 | dhaka
# Processing Record 3 of Set 7 | olga
# Processing Record 4 of Set 7 | kamenka
# Processing Record 5 of Set 7 | izhma
# Processing Record 6 of Set 7 | yulara
# Processing Record 7 of Set 7 | boa esperanca
# Processing Record 8 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 9 of Set 7 | chatham
# Processing Record 10 of Set 7 | praia
# Processing Record 11 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 12 of Set 7 | vuktyl
# Processing Record 13 of Set 7 | bredasdorp
# Processing Record 14 of Set 7 | sangar
# Processing Record 15 of Set 7 | mumbwa
# Processing Record 16 of Set 7 | verkhoyansk
# Processing Record 17 of Set 7 | tshikapa
# Processing Record 18 of Set 7 | gimli
# Processing Record 19 of Set 7 | maralal
# Processing Record 20 of Set 7 | camacha
# Processing Record 21 of Set 7 | bay roberts
# Processing Record 22 of Set 7 | providencia
# Processing Record 23 of Set 7 | sherghati
# Processing Record 24 of Set 7 | kaitangata
# Processing Record 25 of Set 7 | tupiza
# Processing Record 26 of Set 7 | tarpon springs
# Processing Record 27 of Set 7 | bilma
# Processing Record 28 of Set 7 | wajid
# Processing Record 29 of Set 7 | karasjok
# Processing Record 30 of Set 7 | teya
# Processing Record 31 of Set 7 | toccoa
# Processing Record 32 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 7 | kisesa
# Processing Record 34 of Set 7 | bonavista
# Processing Record 35 of Set 7 | ca mau
# Processing Record 36 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 7 | taksimo
# Processing Record 38 of Set 7 | avera
# Processing Record 39 of Set 7 | havoysund
# Processing Record 40 of Set 7 | przeworsk
# Processing Record 41 of Set 7 | sorland
# Processing Record 42 of Set 7 | havre-saint-pierre
# Processing Record 43 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 7 | vestmanna
# Processing Record 45 of Set 7 | saint-philippe
# Processing Record 46 of Set 7 | stornoway
# Processing Record 47 of Set 7 | hendek
# Processing Record 48 of Set 7 | college
# Processing Record 49 of Set 7 | vao
# Processing Record 50 of Set 7 | sonda
# Processing Record 1 of Set 8 | te anau
# Processing Record 2 of Set 8 | shwebo
# Processing Record 3 of Set 8 | puerto carreno
# Processing Record 4 of Set 8 | santa cruz
# Processing Record 5 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 8 | thurso
# Processing Record 7 of Set 8 | manhattan
# Processing Record 8 of Set 8 | shushenskoye
# Processing Record 9 of Set 8 | nikolskoye
# Processing Record 10 of Set 8 | tapaua
# City not found. Skipping...
# Processing Record 11 of Set 8 | steamboat springs
# Processing Record 12 of Set 8 | araouane
# Processing Record 13 of Set 8 | dukat
# Processing Record 14 of Set 8 | lengshuitan
# Processing Record 15 of Set 8 | lakes entrance
# Processing Record 16 of Set 8 | praia da vitoria
# Processing Record 17 of Set 8 | bataipora
# Processing Record 18 of Set 8 | kampong cham
# Processing Record 19 of Set 8 | ginir
# Processing Record 20 of Set 8 | kanchanaburi
# Processing Record 21 of Set 8 | warrnambool
# Processing Record 22 of Set 8 | santa maria
# Processing Record 23 of Set 8 | marica
# Processing Record 24 of Set 8 | palana
# Processing Record 25 of Set 8 | namibe
# Processing Record 26 of Set 8 | la ronge
# Processing Record 27 of Set 8 | yamasaki
# Processing Record 28 of Set 8 | ugoofaaru
# Processing Record 29 of Set 8 | marsh harbour
# Processing Record 30 of Set 8 | bahia honda
# Processing Record 31 of Set 8 | hami
# Processing Record 32 of Set 8 | walvis bay
# Processing Record 33 of Set 8 | marshall
# Processing Record 34 of Set 8 | itarema
# Processing Record 35 of Set 8 | meridian
# Processing Record 36 of Set 8 | cocoa beach
# Processing Record 37 of Set 8 | oyek
# Processing Record 38 of Set 8 | itaituba
# Processing Record 39 of Set 8 | uruzgan
# Processing Record 40 of Set 8 | antofagasta
# Processing Record 41 of Set 8 | muravlenko
# Processing Record 42 of Set 8 | thamaga
# Processing Record 43 of Set 8 | yabrud
# Processing Record 44 of Set 8 | tessalit
# Processing Record 45 of Set 8 | shenjiamen
# Processing Record 46 of Set 8 | suez
# Processing Record 47 of Set 8 | creel
# Processing Record 48 of Set 8 | sur
# Processing Record 49 of Set 8 | road town
# Processing Record 50 of Set 8 | nagato
# Processing Record 1 of Set 9 | grand gaube
# Processing Record 2 of Set 9 | bandarbeyla
# Processing Record 3 of Set 9 | sarankhola
# Processing Record 4 of Set 9 | byron bay
# Processing Record 5 of Set 9 | sola
# Processing Record 6 of Set 9 | labuhan
# Processing Record 7 of Set 9 | alice springs
# Processing Record 8 of Set 9 | koroni
# Processing Record 9 of Set 9 | coos bay
# Processing Record 10 of Set 9 | nikki
# Processing Record 11 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 12 of Set 9 | kapuskasing
# Processing Record 13 of Set 9 | nuevo progreso
# Processing Record 14 of Set 9 | halmstad
# Processing Record 15 of Set 9 | olds
# Processing Record 16 of Set 9 | socorro
# Processing Record 17 of Set 9 | kruisfontein
# Processing Record 18 of Set 9 | yuscaran
# Processing Record 19 of Set 9 | eagle
# Processing Record 20 of Set 9 | pimampiro
# Processing Record 21 of Set 9 | san patricio
# Processing Record 22 of Set 9 | concepcion
# Processing Record 23 of Set 9 | tual
# Processing Record 24 of Set 9 | pochutla
# Processing Record 25 of Set 9 | altos del rosario
# Processing Record 26 of Set 9 | henties bay
# Processing Record 27 of Set 9 | tyup
# Processing Record 28 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 29 of Set 9 | tanjong karang
# City not found. Skipping...
# Processing Record 30 of Set 9 | alofi
# Processing Record 31 of Set 9 | daru
# Processing Record 32 of Set 9 | am timan
# Processing Record 33 of Set 9 | matadi
# Processing Record 34 of Set 9 | aljezur
# Processing Record 35 of Set 9 | ngorongoro
# Processing Record 36 of Set 9 | puerto leguizamo
# Processing Record 37 of Set 9 | manapparai
# Processing Record 38 of Set 9 | taft
# Processing Record 39 of Set 9 | waipawa
# Processing Record 40 of Set 9 | porto nacional
# Processing Record 41 of Set 9 | hokitika
# Processing Record 42 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 9 | geraldton
# Processing Record 44 of Set 9 | aldan
# Processing Record 45 of Set 9 | saint george
# Processing Record 46 of Set 9 | espita
# Processing Record 47 of Set 9 | omsukchan
# Processing Record 48 of Set 9 | meulaboh
# Processing Record 49 of Set 9 | obzor
# Processing Record 50 of Set 9 | kamina
# Processing Record 1 of Set 10 | krasnogvardeyskoye
# Processing Record 2 of Set 10 | vostok
# Processing Record 3 of Set 10 | ormond beach
# Processing Record 4 of Set 10 | khasan
# Processing Record 5 of Set 10 | bezhetsk
# Processing Record 6 of Set 10 | benalla
# Processing Record 7 of Set 10 | port hedland
# Processing Record 8 of Set 10 | altay
# Processing Record 9 of Set 10 | kupang
# Processing Record 10 of Set 10 | dobrovice
# Processing Record 11 of Set 10 | elko
# Processing Record 12 of Set 10 | ponta delgada
# Processing Record 13 of Set 10 | eufaula
# Processing Record 14 of Set 10 | homer
# Processing Record 15 of Set 10 | chifeng
# Processing Record 16 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 10 | saint anthony
# Processing Record 18 of Set 10 | celestun
# Processing Record 19 of Set 10 | taseyevo
# Processing Record 20 of Set 10 | san cristobal
# Processing Record 21 of Set 10 | buraydah
# Processing Record 22 of Set 10 | chumikan
# Processing Record 23 of Set 10 | bolshaya murta
# City not found. Skipping...
# Processing Record 24 of Set 10 | belgrade
# Processing Record 25 of Set 10 | muroto
# Processing Record 26 of Set 10 | natal
# Processing Record 27 of Set 10 | asuncion
# Processing Record 28 of Set 10 | ahipara
# Processing Record 29 of Set 10 | rurrenabaque
# Processing Record 30 of Set 10 | aleksandrovskoye
# Processing Record 31 of Set 10 | azacualpa
# Processing Record 32 of Set 10 | mwanza
# Processing Record 33 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 34 of Set 10 | cleburne
# Processing Record 35 of Set 10 | olafsvik
# Processing Record 36 of Set 10 | ife
# Processing Record 37 of Set 10 | encruzilhada
# Processing Record 38 of Set 10 | inhambane
# Processing Record 39 of Set 10 | mustasaari
# Processing Record 40 of Set 10 | rabat
# Processing Record 41 of Set 10 | valparaiso
# Processing Record 42 of Set 10 | talah
# City not found. Skipping...
# Processing Record 43 of Set 10 | binzhou
# Processing Record 44 of Set 10 | campbell river
# Processing Record 45 of Set 10 | prince george
# Processing Record 46 of Set 10 | quijingue
# Processing Record 47 of Set 10 | belmonte
# Processing Record 48 of Set 10 | mitzic
# Processing Record 49 of Set 10 | port blair
# Processing Record 50 of Set 10 | tazovskiy
# Processing Record 1 of Set 11 | cap malheureux
# Processing Record 2 of Set 11 | ileza
# Processing Record 3 of Set 11 | caloundra
# Processing Record 4 of Set 11 | forio
# Processing Record 5 of Set 11 | rolandia
# Processing Record 6 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 11 | kulhudhuffushi
# Processing Record 8 of Set 11 | nuuk
# Processing Record 9 of Set 11 | casa grande
# Processing Record 10 of Set 11 | pringsewu
# Processing Record 11 of Set 11 | beyla
# Processing Record 12 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 11 | tommot
# Processing Record 14 of Set 11 | west bay
# Processing Record 15 of Set 11 | katsuura
# Processing Record 16 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 11 | fairbanks
# Processing Record 18 of Set 11 | coachella
# Processing Record 19 of Set 11 | yeppoon
# Processing Record 20 of Set 11 | hualmay
# Processing Record 21 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 22 of Set 11 | toribio
# Processing Record 23 of Set 11 | mendahara
# City not found. Skipping...
# Processing Record 24 of Set 11 | diego de almagro
# Processing Record 25 of Set 11 | adrar
# Processing Record 26 of Set 11 | port augusta
# Processing Record 27 of Set 11 | opuwo
# Processing Record 28 of Set 11 | quelimane
# Processing Record 29 of Set 11 | cururupu
# Processing Record 30 of Set 11 | maxixe
# Processing Record 31 of Set 11 | baijiantan
# Processing Record 32 of Set 11 | gilgit
# Processing Record 33 of Set 11 | el dovio
# Processing Record 34 of Set 11 | muyezerskiy
# Processing Record 35 of Set 11 | altamont
# Processing Record 36 of Set 11 | wakkanai
# Processing Record 37 of Set 11 | etchoropo
# Processing Record 38 of Set 11 | tateyama
# Processing Record 39 of Set 11 | coahuayana
# Processing Record 40 of Set 11 | san lorenzo
# Processing Record 41 of Set 11 | silleda
# Processing Record 42 of Set 11 | kajaani
# Processing Record 43 of Set 11 | taoudenni
# Processing Record 44 of Set 11 | narsaq
# Processing Record 45 of Set 11 | pilar
# Processing Record 46 of Set 11 | ginda
# Processing Record 47 of Set 11 | haverfordwest
# Processing Record 48 of Set 11 | arrifes
# Processing Record 49 of Set 11 | luwuk
# Processing Record 50 of Set 11 | namatanai
# Processing Record 1 of Set 12 | maridi
# Processing Record 2 of Set 12 | vanavara
# Processing Record 3 of Set 12 | galt
# Processing Record 4 of Set 12 | znamenskoye
# Processing Record 5 of Set 12 | charleston
# Processing Record 6 of Set 12 | baykit
# Processing Record 7 of Set 12 | bereda
# Processing Record 8 of Set 12 | san andres
# Processing Record 9 of Set 12 | korla
# Processing Record 10 of Set 12 | manado
# Processing Record 11 of Set 12 | dubti
# Processing Record 12 of Set 12 | keti bandar
# Processing Record 13 of Set 12 | quthing
# Processing Record 14 of Set 12 | riyadh
# Processing Record 15 of Set 12 | chapais
# Processing Record 16 of Set 12 | kankon
# Processing Record 17 of Set 12 | pavlohrad
# Processing Record 18 of Set 12 | wauconda
# Processing Record 19 of Set 12 | dalian
# Processing Record 20 of Set 12 | aanekoski
# Processing Record 21 of Set 12 | boundiali
# Processing Record 22 of Set 12 | cabatuan
# Processing Record 23 of Set 12 | wajima
# Processing Record 24 of Set 12 | yabelo
# Processing Record 25 of Set 12 | pisco
# Processing Record 26 of Set 12 | ushtobe
# Processing Record 27 of Set 12 | yanchukan
# City not found. Skipping...
# Processing Record 28 of Set 12 | itupiranga
# Processing Record 29 of Set 12 | arlit
# Processing Record 30 of Set 12 | kuytun
# Processing Record 31 of Set 12 | nadym
# Processing Record 32 of Set 12 | aykhal
# Processing Record 33 of Set 12 | genhe
# Processing Record 34 of Set 12 | cienaga de flores
# City not found. Skipping...
# Processing Record 35 of Set 12 | constantine
# Processing Record 36 of Set 12 | ramet
# Processing Record 37 of Set 12 | devli
# Processing Record 38 of Set 12 | usagara
# Processing Record 39 of Set 12 | mkokotoni
# Processing Record 40 of Set 12 | sokolo
# Processing Record 41 of Set 12 | matamoros
# Processing Record 42 of Set 12 | baghdad
# Processing Record 43 of Set 12 | santa fe
# Processing Record 44 of Set 12 | nouadhibou
# Processing Record 45 of Set 12 | lamu
# Processing Record 46 of Set 12 | porto santo
# Processing Record 47 of Set 12 | leshukonskoye
# Processing Record 48 of Set 12 | coari
# Processing Record 49 of Set 12 | nenjiang
# Processing Record 50 of Set 12 | maneadero
# Processing Record 1 of Set 13 | leningradskiy
# Processing Record 2 of Set 13 | kota tinggi
# Processing Record 3 of Set 13 | apatou
# Processing Record 4 of Set 13 | anadyr
# Processing Record 5 of Set 13 | timra
# Processing Record 6 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 7 of Set 13 | hervey bay
# Processing Record 8 of Set 13 | dekalb
# Processing Record 9 of Set 13 | oeiras do para
# Processing Record 10 of Set 13 | necochea
# Processing Record 11 of Set 13 | maceio
# Processing Record 12 of Set 13 | chemal
# Processing Record 13 of Set 13 | mweka
# Processing Record 14 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 13 | manavalakurichi
# Processing Record 16 of Set 13 | edson
# Processing Record 17 of Set 13 | eureka
# Processing Record 18 of Set 13 | tambovka
# Processing Record 19 of Set 13 | neiafu
# Processing Record 20 of Set 13 | qaqortoq
# Processing Record 21 of Set 13 | ballina
# Processing Record 22 of Set 13 | yokadouma
# Processing Record 23 of Set 13 | ocampo
# Processing Record 24 of Set 13 | yanam
# Processing Record 25 of Set 13 | njombe
# Processing Record 26 of Set 13 | nemuro
# Processing Record 27 of Set 13 | weligama
# Processing Record 28 of Set 13 | port hardy
# Processing Record 29 of Set 13 | kasempa
# Processing Record 30 of Set 13 | turayf
# Processing Record 31 of Set 13 | biak
# Processing Record 32 of Set 13 | hay river
# Processing Record 33 of Set 13 | yuanping
# Processing Record 34 of Set 13 | hwange
# Processing Record 35 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 13 | galle
# Processing Record 37 of Set 13 | ulundi
# Processing Record 38 of Set 13 | ojinaga
# Processing Record 39 of Set 13 | okhotsk
# Processing Record 40 of Set 13 | tahoua
# Processing Record 41 of Set 13 | calama
# Processing Record 42 of Set 13 | adeje
# Processing Record 43 of Set 13 | berbera
# Processing Record 44 of Set 13 | kenora
# Processing Record 45 of Set 13 | kargil
# Processing Record 46 of Set 13 | aden
# Processing Record 47 of Set 13 | sandnessjoen
# Processing Record 48 of Set 13 | todos santos
# Processing Record 49 of Set 13 | santa rosa
# Processing Record 50 of Set 13 | srandakan
# Processing Record 1 of Set 14 | khuzdar
# Processing Record 2 of Set 14 | ha giang
# Processing Record 3 of Set 14 | acajutiba
# Processing Record 4 of Set 14 | adelaide
# Processing Record 5 of Set 14 | gualaco
# Processing Record 6 of Set 14 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 7 of Set 14 | romny
# Processing Record 8 of Set 14 | chaohu
# Processing Record 9 of Set 14 | witu
# Processing Record 10 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 14 | marfino
# Processing Record 12 of Set 14 | nha trang
# Processing Record 13 of Set 14 | januaria
# Processing Record 14 of Set 14 | auki
# Processing Record 15 of Set 14 | agadez
# Processing Record 16 of Set 14 | tecolutla
# Processing Record 17 of Set 14 | broome
# Processing Record 18 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 14 | vallenar
# Processing Record 20 of Set 14 | sulangan
# Processing Record 21 of Set 14 | khandyga
# Processing Record 22 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 14 | santo anastacio
# Processing Record 24 of Set 14 | thinadhoo
# Processing Record 25 of Set 14 | kholm
# Processing Record 26 of Set 14 | coihaique
# Processing Record 27 of Set 14 | redmond
# Processing Record 28 of Set 14 | aporawan
# City not found. Skipping...
# Processing Record 29 of Set 14 | sarkikaraagac
# Processing Record 30 of Set 14 | juchitan
# City not found. Skipping...
# Processing Record 31 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 14 | fortuna
# Processing Record 33 of Set 14 | milkovo
# Processing Record 34 of Set 14 | russell
# Processing Record 35 of Set 14 | jintur
# Processing Record 36 of Set 14 | dublin
# Processing Record 37 of Set 14 | moose factory
# Processing Record 38 of Set 14 | alyangula
# Processing Record 39 of Set 14 | plettenberg bay
# Processing Record 40 of Set 14 | lethem
# Processing Record 41 of Set 14 | guozhen
# Processing Record 42 of Set 14 | cherskiy
# Processing Record 43 of Set 14 | denpasar
# Processing Record 44 of Set 14 | luderitz
# Processing Record 45 of Set 14 | helena
# Processing Record 46 of Set 14 | finnsnes
# Processing Record 47 of Set 14 | angra
# City not found. Skipping...
# Processing Record 48 of Set 14 | tynda
# Processing Record 49 of Set 14 | shahrud
# Processing Record 50 of Set 14 | batagay-alyta
# Processing Record 1 of Set 15 | asosa
# Processing Record 2 of Set 15 | beira
# Processing Record 3 of Set 15 | la paz
# Processing Record 4 of Set 15 | marsa matruh
# Processing Record 5 of Set 15 | naberera
# Processing Record 6 of Set 15 | tiarei
# Processing Record 7 of Set 15 | buchanan
# Processing Record 8 of Set 15 | saint-francois
# Processing Record 9 of Set 15 | zolotinka
# City not found. Skipping...
# Processing Record 10 of Set 15 | rosetta
# Processing Record 11 of Set 15 | madang
# Processing Record 12 of Set 15 | hurghada
# Processing Record 13 of Set 15 | egvekinot
# Processing Record 14 of Set 15 | sobolevo
# Processing Record 15 of Set 15 | ayer itam
# City not found. Skipping...
# Processing Record 16 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 15 | colac
# Processing Record 18 of Set 15 | hede
# Processing Record 19 of Set 15 | grindavik
# Processing Record 20 of Set 15 | vila franca do campo
# Processing Record 21 of Set 15 | wellington
# Processing Record 22 of Set 15 | huarmey
# Processing Record 23 of Set 15 | sayat
# Processing Record 24 of Set 15 | vaitape
# Processing Record 25 of Set 15 | chara
# Processing Record 26 of Set 15 | huangchuan
# Processing Record 27 of Set 15 | tairua
# Processing Record 28 of Set 15 | viedma
# Processing Record 29 of Set 15 | ouadda
# Processing Record 30 of Set 15 | chebsara
# Processing Record 31 of Set 15 | deniliquin
# Processing Record 32 of Set 15 | kango
# Processing Record 33 of Set 15 | rodas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weather_database_df = pd.DataFrame(city_data)

weather_database_df=weather_database_df[["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]]
weather_database_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Louiseville      CA  46.2559  -72.9415     10.40        56           5
# 1         Evensk      RU  61.9500  159.2333      3.40        88         100
# 2       Klaksvik      FO  62.2266   -6.5890     32.00        55          43
# 3      Jamestown      US  42.0970  -79.2353     18.00        79           1
# 4        Qaanaaq      GL  77.4840  -69.3632     -5.31        75          99
# ..           ...     ...      ...       ...       ...       ...         ...
# 669       Ouadda      CF   8.0777   22.4007     69.42        23          41
# 670     Chebsara      RU  59.2002   38.8356     17.31        97         100
# 671   Deniliquin      AU -35.5333  144.9667     81.00        40           0
# 672        Kango      GA   0.1943   10.0951     73.87        96         100
# 673        Rodas      CU  22.3408  -80.5572     68.00        77          61
#
#      Wind Speed Current Description
# 0          8.05           clear sky
# 1         26.82     overcast clouds
# 2         26.46    scattered clouds
# 3          5.75           clear sky
# 4          2.66     overcast clouds
# ..          ...                 ...
# 669        6.98    scattered clouds
# 670        9.19                snow
# 671        4.47           clear sky
# 672        0.78     overcast clouds
# 673        9.22          light rain
#
# [674 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_database_df.to_csv(output_data_file, index_label="City_ID")
